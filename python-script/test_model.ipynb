# %%
from keras.models import clone_model, load_model
from skimage.color import rgb2lab, lab2rgb
import numpy as np
import os
import cv2 as cv
from keras.models import load_model
from keras.losses import MeanSquaredError
from keras.utils import CustomObjectScope
from keras.metrics import mean_squared_error
from datetime import datetime

# %%
mse = mean_squared_error



with CustomObjectScope({'mse': mse}):
    model = load_model("Models/buildings_high2.h5")
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
mse = mean_squared_error



with CustomObjectScope({'mse': mse}):
    model_red = load_model("Models\\inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5")
    model_red.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

model_red.summary()

# %%
def color_me2(image1, model):
    original_shape = image1.shape[:2]
    #image1 = np.array(image1, dtype=float)
    X = rgb2lab(1.0/255*image1)[:, :, 0]
    
    X = X.reshape(1, original_shape[0], original_shape[1], 1)

    output = model.predict(X)
    output = output * 128
    
    # output_resized = resize(output[0], (original_shape[0], original_shape[1], 2))

    cur = np.zeros((original_shape[0], original_shape[1], 3))
    cur[:, :, 0] = X[0, :, :, 0]
    # Burada output yerine output_resized kullanılabilir.
    cur[:, :, 1:] = output[0][:original_shape[0], :original_shape[1], :]

    # Y = (1.0/255*cur)[:,:,1:]
    # Y /= 128
    
    # Y = Y.reshape(1, original_shape[0], original_shape[1], 2)   
    
    # print(model.evaluate(X, Y, batch_size=1))
    
    return lab2rgb(cur)

def color_me3(image):
    height, width = image.shape[:2]
    cur = np.zeros((height, width, 3))
    red = color_me2(image,model_red)
    green = color_me2(image,model_green)
    blue = color_me2(image,model_blue)

    for i in range(height):
        for j in range(width):
            pixel_red = red[i,j][2]
            pixel_green = green[i,j][1]
            pixel_blue = blue[i,j][1]
            cur[i,j] = [pixel_blue, pixel_green, pixel_red]

    return cur

# %%
def colorize_video(input_video_path, output_video_name, model):
    
    cap = cv.VideoCapture(input_video_path)
    
    frame_width = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
    fps = 60
    total_frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    codec = int(cap.get(cv.CAP_PROP_FOURCC))
    codec2 = cv.VideoWriter_fourcc(*"mpv4")


    out = cv.VideoWriter(output_video_name, codec, fps, (frame_width, frame_height))
    
    count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        
        colorized_frame = color_me2(frame, model)
        colorized_frame = ((colorized_frame)*255).astype(np.uint8)

        out.write(colorized_frame)

        
        

        count+=1
        print(count, "/", total_frames)

    
    cap.release()
    out.release()

# %%
now = datetime.now()
name = now.strftime("%d%m%Y_%H%M%S")

input_video = "Test\\VID_48830720_044431_226.mp4"
output_video = f"Test\\{name}.mp4"

colorize_video(input_video, output_video, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 2 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 3 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 4 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 5 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 6 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 7 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 8 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 9 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 10 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 11 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 12 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 13 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 14 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 15 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 16 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 17 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 18 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 19 / 344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 20 / 344
# ...

# %%
get_image = cv.imread("Test\\test10.jpg")
#get_image = cv.resize(get_image, (get_image.shape[1]//3, get_image.shape[0]//3))
#cur = color_me2(get_image)
#image = lab2rgb(cur)
image = (color_me2(get_image, model))

#imagee = rgb2gray(lab2rgb(cur))
cv.imshow("aa", image)
cv.imshow("aaa", get_image)
cv.waitKey()
cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step

# %%
model.summary()
