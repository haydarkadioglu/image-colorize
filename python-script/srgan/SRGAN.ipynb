# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras import layers, Model
from sklearn.model_selection import train_test_split

import numpy as np
from keras import Model
from keras.layers import Conv2D, PReLU,BatchNormalization, Flatten
from keras.layers import UpSampling2D, LeakyReLU, Dense, Input, add
from tqdm import tqdm
from keras.applications import VGG19

# %%
def res_block(ip):
    
    res_model = Conv2D(64, (3,3), padding = "same")(ip)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    res_model = PReLU(shared_axes = [1,2])(res_model)
    
    res_model = Conv2D(64, (3,3), padding = "same")(res_model)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    
    return add([ip,res_model])

def upscale_block(ip):
    
    up_model = Conv2D(256, (3,3), padding="same")(ip)
    up_model = UpSampling2D( size = 2 )(up_model)
    up_model = PReLU(shared_axes=[1,2])(up_model)
    
    return up_model

#Generator model
def create_gen(gen_ip, num_res_block):
    layers = Conv2D(64, (9,9), padding="same")(gen_ip)
    layers = PReLU(shared_axes=[1,2])(layers)

    temp = layers

    for i in range(num_res_block):
        layers = res_block(layers)

    layers = Conv2D(64, (3,3), padding="same")(layers)
    layers = BatchNormalization(momentum=0.5)(layers)
    layers = add([layers,temp])

    layers = upscale_block(layers)
    layers = upscale_block(layers)

    op = Conv2D(3, (9,9), padding="same")(layers)

    return Model(inputs=gen_ip, outputs=op)

#Descriminator block that will be used to construct the discriminator
def discriminator_block(ip, filters, strides=1, bn=True):
    
    disc_model = Conv2D(filters, (3,3), strides = strides, padding="same")(ip)
    
    if bn:
        disc_model = BatchNormalization( momentum=0.8 )(disc_model)
    
    disc_model = LeakyReLU( alpha=0.2 )(disc_model)
    
    return disc_model


#Descriminartor, as described in the original paper
def create_disc(disc_ip):

    df = 64
    
    d1 = discriminator_block(disc_ip, df, bn=False)
    d2 = discriminator_block(d1, df, strides=2)
    d3 = discriminator_block(d2, df*2)
    d4 = discriminator_block(d3, df*2, strides=2)
    d5 = discriminator_block(d4, df*4)
    d6 = discriminator_block(d5, df*4, strides=2)
    d7 = discriminator_block(d6, df*8)
    d8 = discriminator_block(d7, df*8, strides=2)
    
    d8_5 = Flatten()(d8)
    d9 = Dense(df*16)(d8_5)
    d10 = LeakyReLU(alpha=0.2)(d9)
    validity = Dense(1, activation='sigmoid')(d10)

    return Model(disc_ip, validity)

# %%
def build_vgg(hr_shape):
    
    vgg = VGG19(weights="imagenet",include_top=False, input_shape=hr_shape)
    
    return Model(inputs=vgg.inputs, outputs=vgg.layers[10].output)

# %%

#Combined model
def create_comb(gen_model, disc_model, vgg, lr_ip, hr_ip):
    gen_img = gen_model(lr_ip)
    
    gen_features = vgg(gen_img)
    
    disc_model.trainable = False
    validity = disc_model(gen_img)
    
    return Model(inputs=[lr_ip, hr_ip], outputs=[validity, gen_features])

# %%
m_lr_list = []
m_hr_list = []

# %%
def load_data(data_dir, size):
    count = 0
    for filename in os.listdir(data_dir):
        image = cv2.imread(os.path.join(data_dir, filename))
        height, width, c = image.shape
        image = cv2.resize(image, dsize=size)
        m_hr_list.append(image)
        count += 1
        print(count, " - ", filename)
        

    print("Dosyalar Yüklendi")

load_data("F:\\Restoresyon\\data\\mix", (512,512))
# Out:
# 1  -  -church-brick-place-of-worship-avenue-english-scottish-estate-modest-1216073.jpg
-  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL420.jpg
# 728  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL421.jpg
# 729  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL422.jpg
# 730  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL423.jpg
# 731  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL424.jpg
# 732  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL425.jpg
# 733  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL426.jpg
# 734  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL427.jpg
# 735  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL428.jpg
# 736  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL429.jpg
# 737  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL43.jpg
# 738  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL430.jpg
# 739  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL431.jpg
# 740  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL432.jpg
# 741  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL433.jpg
# 742  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL434.jpg
# 743  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL435.jpg
# 744  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL436.jpg
# 745  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL437.jpg
# 746  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL438.jpg
# 747  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL439.jpg
# 748  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL44.jpg
# 749  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL440.jpg
# 750  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL441.jpg
# 751  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL442.jpg
# 752  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL443.jpg
# 753  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL45.jpg
# 754  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL46.jpg
# 755  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL47.jpg
# 756  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL48.jpg
# 757  -  icaFjIssJWkNxUq8Ccp_0n03Ens8zquywlOzWwzCfdVqGvWplWmd1O1OKg_hTW5QDn3vjXk94wL49.jpg
# 758  -  meerkat-wallpapers-45735-1360647-7895078.png
# 759  -  pexels-photo-195050.jpeg
# 760  -  screenshot_20190301-1147386623021178236789661.png
# 761  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg13.jpg
# 762  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg14.jpg
# 763  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg15.jpg
# 764  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg16.jpg
# 765  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg17.jpg
# 766  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg18.jpg
# 767  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg19.jpg
# 768  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg20.jpg
# 769  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg21.jpg
# 770  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg25.jpg
# 771  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg26.jpg
# 772  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg27.jpg
# 773  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg28.jpg
# 774  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg29.jpg
# 775  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg30.jpg
# 776  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg31.jpg
# 777  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg32.jpg
# 778  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg33.jpg
# 779  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg37.jpg
# 780  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg38.jpg
# 781  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg39.jpg
# 782  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg40.jpg
# 783  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg41.jpg
# 784  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg42.jpg
# 785  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg43.jpg
# 786  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg44.jpg
# 787  -  wepBwNcwZVHlHRYENVaD-u3_9jOQRutqDlODoxgKJT36Fml9nZ3pgFmCjns9wQJIOuXTqcHBt9qg45.jpg
# 788  -  ws_Jungle_Animals_Five_1280x1024.jpg
# 789  -  Z2EQ.jpg
# 790  -  zhivotnye-lvy-kamen-lvyonok-289869.jpg
# 791  -  zverki-surikaty-gruppa-588fa4b.jpg
# 792  -  _original.jpg
# Dosyalar Yüklendi

# %%
import random
import numpy as np
image_number = random.randint(0, len(m_lr_list)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(m_lr_list[image_number])
plt.subplot(122)
plt.imshow(m_hr_list[image_number])
plt.show()

# %%
#Scale values
lr_images = np.array(m_lr_list, dtype=np.float32) / 255.
hr_images = np.array(m_hr_list, dtype=np.float32) / 255.

#Split to train and test
lr_train, lr_test, hr_train, hr_test = train_test_split(lr_images, hr_images, 
                                                      test_size=0.15, random_state=42)

# %%
hr_shape = (hr_train.shape[1], hr_train.shape[2], hr_train.shape[3])
lr_shape = (lr_train.shape[1], lr_train.shape[2], lr_train.shape[3])

lr_ip = Input(shape=lr_shape)
hr_ip = Input(shape=hr_shape)

# %%
generator = create_gen(lr_ip, num_res_block = 16)
# generator.summary()

discriminator = create_disc(hr_ip)
discriminator.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
# discriminator.summary()

vgg = build_vgg((None,None,3))
print(vgg.summary())
vgg.trainable = False

gan_model = create_comb(generator, discriminator, vgg, lr_ip, hr_ip)
# Out:
# C:\Users\ahayd\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_45"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)     │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,325,568 (8.87 MB)
#  Trainable params: 2,325,568 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
gan_model.compile(loss=["binary_crossentropy", "mse"], loss_weights=[1e-3, 1], optimizer="adam")
gan_model.summary()
# Out:
# Model: "functional_47"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_41       │ (None, 512, 512,  │  2,044,291 │ input_layer_3[0]… │
# │ (Functional)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_4       │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_43       │ (None, 1)         │ 541,565,7… │ functional_41[0]… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_45       │ (None, 128, 128,  │  2,325,568 │ functional_41[0]… │
# │ (Functional)        │ 256)              │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 545,935,620 (2.03 GB)
#  Trainable params: 2,040,067 (7.78 MB)
#  Non-trainable params: 543,895,553 (2.03 GB)

# %%
batch_size = 1  
train_lr_batches = []
train_hr_batches = []
for it in range(int(hr_train.shape[0] / batch_size)):
    start_idx = it * batch_size
    end_idx = start_idx + batch_size
    train_hr_batches.append(hr_train[start_idx:end_idx])
    train_lr_batches.append(lr_train[start_idx:end_idx])

# %%
epochs = 5
#Enumerate training over epochs
for e in range(epochs):
    
    fake_label = np.zeros((batch_size, 1)) # Assign a label of 0 to all fake (generated images)
    real_label = np.ones((batch_size,1)) # Assign a label of 1 to all real images.
    
    #Create empty lists to populate gen and disc losses. 
    g_losses = []
    d_losses = []
    
    #Enumerate training over batches. 
    for b in tqdm(range(len(train_hr_batches))):
        lr_imgs = train_lr_batches[b] #Fetch a batch of LR images for training
        hr_imgs = train_hr_batches[b] #Fetch a batch of HR images for training
        
        fake_imgs = generator.predict_on_batch(lr_imgs) #Fake images
        
        #First, train the discriminator on fake and real HR images. 
        discriminator.trainable = True
        d_loss_gen = discriminator.train_on_batch(fake_imgs, fake_label)
        d_loss_real = discriminator.train_on_batch(hr_imgs, real_label)
        
        #Now, train the generator by fixing discriminator as non-trainable
        discriminator.trainable = False
        
        #Average the discriminator loss, just for reporting purposes. 
        d_loss = 0.5 * np.add(d_loss_gen, d_loss_real) 
        
        #Extract VGG features, to be used towards calculating loss
        image_features = vgg.predict(hr_imgs)
     
        #Train the generator via GAN. 
        #Remember that we have 2 losses, adversarial loss and content (VGG) loss
        g_loss, _, _ = gan_model.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])
        
        #Save losses to a list so we can average and report. 
        d_losses.append(d_loss)
        g_losses.append(g_loss)
        
    #Convert the list of losses to an array to make it easy to average    
    g_losses = np.array(g_losses)
    d_losses = np.array(d_losses)
    
    #Calculate the average losses for generator and discriminator
    g_loss = np.sum(g_losses, axis=0) / len(g_losses)
    d_loss = np.sum(d_losses, axis=0) / len(d_losses)
    
    #Report the progress during training. 
    print("epoch:", e+1 ,"g_loss:", g_loss, "d_loss:", d_loss)

    if (e+1) % 10 == 0: #Change the frequency for model saving, if needed
        #Save the generator after every n epochs (Usually 10 epochs)
        generator.save("gen_e_"+ str(e+1) +".h5")
# Out:
#   0%|          | 0/673 [00:00<?, ?it/s]
